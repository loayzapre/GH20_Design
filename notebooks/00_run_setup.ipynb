# %%
from gh20_design.paths import RunParams, make_run_id, make_run_dirs, write_run_config

p = RunParams(
    nr=0.90,
    bitscore=100,
    inflation=2.0,
    max_targets=5000,
)

run_id = make_run_id(p, prefix="gh20")
D = make_run_dirs("../outputs", run_id)

write_run_config(D["run"], p, extra={"note": "baseline run"})
print("RUN_DIR =", D["run"])
# Out:
# RUN_DIR = ../outputs/runs/gh20__2026-01-31__nr90__bs100__I2.0__t5000
