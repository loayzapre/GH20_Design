# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd
import sys
import numpy as np

ROOT = Path("..").resolve()
DATA = ROOT / "data"
OUT  = ROOT / "outputs"

DATA.mkdir(exist_ok=True)
(DATA / "raw").mkdir(parents=True, exist_ok=True)
(DATA / "processed").mkdir(parents=True, exist_ok=True)

print(ROOT)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/zealot/GH20_Design

# %%
ROOT = Path.cwd().resolve().parent

DATA = ROOT / "data"
RAW = DATA / "raw"
PRO = DATA / "processed"

OUT = ROOT / "outputs"
NB = ROOT / "notebooks"

for p in [DATA, RAW, PRO, OUT]:
    p.mkdir(parents=True, exist_ok=True)

print("ROOT:", ROOT)
print("PYTHON:", sys.executable)
print("CWD:", Path.cwd())
# Out:
# ROOT: /home/zealot/GH20_Design
# PYTHON: /home/zealot/GH20_Design/.venv/bin/python
# CWD: /home/zealot/GH20_Design/notebooks
